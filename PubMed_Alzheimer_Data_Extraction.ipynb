# %% [markdown]
# # PubMed Alzheimer Data Extraction and PDF Downloader
#
# This notebook demonstrates how to download free full‑text PDFs from PubMed Central (PMC) using a list of PubMed IDs (PMIDs) and PMC IDs (PMCIDs) provided in a CSV file.
#
# This notebook performs the following tasks:
# - Queries PubMed for free full-text articles on Alzheimer's Disease (2020–2024)
# - Filters for 'Clinical Trial' and 'Review' types
# - Extracts metadata and writes it to CSV
#
# Once the PubMed metadata info extraction is completed the workflow downloads the open-access full text articles in pdf format.
#
# The following steps are outlined:
#
# 1. **Read** a CSV file containing metadata for Alzheimer’s disease articles.
# 2. **Filter** rows to retain only records published between 2020 and 2024 (inclusive).
# 3. **Retrieve** publication type information for each PMID using the NCBI Entrez API.
# 4. **Select** only those articles whose publication type list contains "Clinical Trial" or "Review" (case‑insensitive).
# 5. **Scrape** the PMC article page via PMCID scraping to find a direct link to the PDF.
# 6. **Download** full-text PDFs and save it local drive.
#
# An NCBI API key is used to permit up to 10 requests per second【287421594061082†L135-L141】. Remember to replace the `EMAIL` constant with your own email address before running the notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install biopython beautifulsoup4 requests
# Out:
# Requirement already satisfied: biopython in /usr/local/lib/python3.11/dist-packages (1.85)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython) (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.8.3)

# %%
import csv
import os
import re
import time
import xml.etree.ElementTree as ET
from typing import Dict, Iterable, List, Tuple

import requests
from bs4 import BeautifulSoup
from Bio import Entrez

EMAIL = 'aritra.lahiri@torontomu.ca' #Insert your own email
API_KEY = 'xxxxxxx' #Insert your NCBI API key
WAIT_TIME = 0.12

Entrez.email = EMAIL
Entrez.api_key = API_KEY

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
        "(KHTML, like Gecko) Chrome/115.0 Safari/537.36"
    ),
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
}

def publication_matches(pub_types: List[str], targets: List[str]) -> bool:
    pub_types_lower = [pt.lower() for pt in pub_types]
    targets_lower = [t.lower() for t in targets]
    return any(pt in pub_types_lower for pt in targets_lower)

def parse_pubmed_xml(record_xml: str) -> Dict[str, str]:
    try:
        root = ET.fromstring(record_xml)
    except Exception:
        return {}
    article = root.find('.//PubmedArticle')
    if article is None:
        return {}
    result = {
        'pmid': '', 'title': '', 'authors': [], 'first_author': '',
        'journal': '', 'volume': '', 'issue': '', 'pages': '',
        'pub_year': '', 'pub_date': '', 'create_date': '',
        'pmcid': '', 'nihms_id': '', 'doi': '', 'pub_types': [],
    }
    pmid_elem = article.find('.//MedlineCitation/PMID')
    if pmid_elem is not None and pmid_elem.text:
        result['pmid'] = pmid_elem.text.strip()
    title_elem = article.find('.//Article/ArticleTitle')
    if title_elem is not None and title_elem.text:
        result['title'] = title_elem.text.strip()
    journal_elem = article.find('.//Article/Journal/Title')
    if journal_elem is not None and journal_elem.text:
        result['journal'] = journal_elem.text.strip()
    volume_elem = article.find('.//Article/Journal/JournalIssue/Volume')
    if volume_elem is not None and volume_elem.text:
        result['volume'] = volume_elem.text.strip()
    issue_elem = article.find('.//Article/Journal/JournalIssue/Issue')
    if issue_elem is not None and issue_elem.text:
        result['issue'] = issue_elem.text.strip()
    pages_elem = article.find('.//Article/Pagination/MedlinePgn')
    if pages_elem is not None and pages_elem.text:
        result['pages'] = pages_elem.text.strip()
    pubdate_elem = article.find('.//Article/Journal/JournalIssue/PubDate')
    pubdate = ''
    if pubdate_elem is not None:
        year_elem = pubdate_elem.find('Year')
        month_elem = pubdate_elem.find('Month')
        day_elem = pubdate_elem.find('Day')
        year = year_elem.text.strip() if year_elem is not None and year_elem.text else ''
        month = month_elem.text.strip() if month_elem is not None and month_elem.text else ''
        day = day_elem.text.strip() if day_elem is not None and day_elem.text else ''
        if year and month and day:
            pubdate = f"{year} {month} {day}"
        elif year and month:
            pubdate = f"{year} {month}"
        elif year:
            pubdate = year
        else:
            medline_date = pubdate_elem.find('MedlineDate')
            if medline_date is not None and medline_date.text:
                pubdate = medline_date.text.strip()
        result['pub_date'] = pubdate
        m = re.search(r'(\d{4})', pubdate)
        if m:
            result['pub_year'] = m.group(1)
    datecreated_elem = article.find('.//MedlineCitation/DateCreated')
    if datecreated_elem is not None:
        y = datecreated_elem.find('Year').text.strip() if datecreated_elem.find('Year') is not None else ''
        mth = datecreated_elem.find('Month').text.strip() if datecreated_elem.find('Month') is not None else ''
        d = datecreated_elem.find('Day').text.strip() if datecreated_elem.find('Day') is not None else ''
        if y and mth and d:
            result['create_date'] = f"{y}/{mth.zfill(2)}/{d.zfill(2)}"
        elif y and mth:
            result['create_date'] = f"{y}/{mth.zfill(2)}"
        elif y:
            result['create_date'] = y
    authors = []
    for auth in article.findall('.//Article/AuthorList/Author'):
        lastname = auth.find('LastName').text.strip() if auth.find('LastName') is not None and auth.find('LastName').text else ''
        forename = auth.find('ForeName').text.strip() if auth.find('ForeName') is not None and auth.find('ForeName').text else ''
        initials = auth.find('Initials').text.strip() if auth.find('Initials') is not None and auth.find('Initials').text else ''
        name = ''
        if lastname and forename:
            name = f"{lastname} {forename}"
        elif lastname and initials:
            name = f"{lastname} {initials}"
        elif lastname:
            name = lastname
        elif forename:
            name = forename
        if name:
            authors.append(name)
    result['authors'] = authors
    result['first_author'] = authors[0] if authors else ''
    pubtypes = []
    for pt in article.findall('.//Article/PublicationTypeList/PublicationType'):
        if pt.text:
            pubtypes.append(pt.text.strip())
    result['pub_types'] = pubtypes
    for aid in article.findall('.//PubmedData/ArticleIdList/ArticleId'):
        id_type = aid.get('IdType')
        id_text = aid.text.strip() if aid.text else ''
        if not id_text:
            continue
        if id_type == 'pmc' or id_type == 'pmcid':
            result['pmcid'] = id_text.replace('PMC', '').replace('pmc', '').strip()
        elif id_type == 'nihms' or id_type == 'nihmsid':
            result['nihms_id'] = id_text
        elif id_type == 'doi':
            result['doi'] = id_text
    return result

def search_pubmed_and_save_csv(query: str, start_year: int, end_year: int, article_types: List[str], max_results: int, output_csv: str) -> None:
    date_query = f'("{start_year}"[Date - Publication] : "{end_year}"[Date - Publication])'
    term = f'({query}) AND {date_query} AND free full text[filter]'
    handle = Entrez.esearch(db='pubmed', term=term, retmax=max_results, usehistory='n')
    search_results = Entrez.read(handle)
    handle.close()
    pmids: List[str] = []
    total_count = 0
    try:
        pmids = search_results['IdList']
        total_count = int(search_results['Count'])
    except Exception:
        pmids = []
        total_count = 0
    print(f'Found {total_count} results; processing {len(pmids)} PMIDs')
    rows: List[Dict[str, str]] = []
    for pmid in pmids:
        try:
            fetch_handle = Entrez.efetch(db='pubmed', id=pmid, retmode='xml')
            record_xml = fetch_handle.read()
            fetch_handle.close()
        except Exception as exc:
            print(f'[!] Error fetching PMID {pmid}: {exc}')
            continue
        data = parse_pubmed_xml(record_xml)
        time.sleep(WAIT_TIME)
        if not data:
            continue
        if not data.get('pmcid'):
            continue
        pub_year = data.get('pub_year')
        if not pub_year:
            continue
        try:
            year_int = int(pub_year)
        except Exception:
            continue
        if year_int < start_year or year_int > end_year:
            continue
        if not publication_matches(data.get('pub_types', []), article_types):
            continue
        citation_parts: List[str] = []
        if data['journal']:
            citation_parts.append(data['journal'])
        if data['pub_date']:
            citation_parts.append(data['pub_date'])
        details = []
        if data['volume']:
            details.append(data['volume'])
        if data['issue']:
            details.append(f"({data['issue']})")
        if data['pages']:
            if details:
                details.append(f":{data['pages']}")
            else:
                details.append(data['pages'])
        if details:
            citation_parts.append(';'.join(details))
        citation = '; '.join(citation_parts)
        if data['doi']:
            citation = f"{citation}. doi: {data['doi']}"
        rows.append({
            'PMID': data['pmid'],
            'Title': data['title'],
            'Authors': '; '.join(data['authors']),
            'Citation': citation,
            'First Author': data['first_author'],
            'Journal/Book': data['journal'],
            'Publication Year': data['pub_year'],
            'Create Date': data['create_date'],
            'PMCID': f"PMC{data['pmcid']}",
            'NIHMS ID': data['nihms_id'],
            'DOI': data['doi'],
        })
    fieldnames = ['PMID','Title','Authors','Citation','First Author','Journal/Book','Publication Year','Create Date','PMCID','NIHMS ID','DOI']
    with open(output_csv, 'w', encoding='utf-8', newline='') as out:
        writer = csv.DictWriter(out, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)
    print(f'Saved {len(rows)} records to {output_csv}')

# %%
# Example usage (uncomment to run)
query= "Alzheimers disease"
start_year = 2020
end_year = 2024
article_types = ['clinical trial', 'review']
max_results = 500 # adjust as needed (e.g., 2000 or more)
output_csv = 'csv-alzheimers-set.csv'
search_pubmed_and_save_csv(query, start_year, end_year, article_types, max_results, output_csv)
# download_pdfs_from_csv(output_csv, start_year, end_year, article_types, output_dir='PMC_Filtered_PDFs')
# Out:
# Found 51860 results; processing 500 PMIDs
# Saved 93 records to csv-alzheimers-set.csv

# %%
import csv
import os
import time
import xml.etree.ElementTree as ET

import requests
from bs4 import BeautifulSoup
from Bio import Entrez

# Configuration
EMAIL = 'aritra.lahiri@torontomu.ca' #Insert your own email
API_KEY = 'xxxxxxx' #Insert your NCBI API key
TARGET_PUB_TYPES = ['clinical trial', 'review']
YEAR_START = 2020
YEAR_END = 2024
DOWNLOAD_DIR = 'PMC_Filtered_PDFs'
WAIT_TIME = 0.12  # seconds between requests to respect rate limits【287421594061082†L135-L141】
CSV_FILE = '/content/csv-alzheimers-set.csv'

# Custom headers to mimic a browser and avoid 403 errors
HEADERS = {
    'User-Agent': (
        'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 '
        '(KHTML, like Gecko) Chrome/115.0 Safari/537.36'
    ),
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8',
}

Entrez.email = EMAIL
Entrez.api_key = API_KEY

# %%
def load_filtered_records(csv_path):
    """Read CSV and return (PMID, PMCID) pairs filtered by publication year."""
    pairs = []
    with open(csv_path, newline='', encoding='utf-8-sig') as handle:
        reader = csv.DictReader(handle)
        for row in reader:
            year_str = row.get('Publication Year', '').strip()
            pmid = row.get('PMID', '').strip()
            pmcid = row.get('PMCID', '').strip()
            if not year_str or not pmid or not pmcid:
                continue
            try:
                year = int(year_str)
            except ValueError:
                continue
            if YEAR_START <= year <= YEAR_END:
                pmcid_clean = pmcid.replace('PMC', '')
                pairs.append((pmid, pmcid_clean))
    return pairs


def fetch_pub_types(pmid):
    """Fetch publication types for a PMID using Entrez."""
    try:
        handle = Entrez.efetch(db='pubmed', id=pmid, retmode='xml')
        xml_data = handle.read()
        handle.close()
        root = ET.fromstring(xml_data)
        types = []
        for elem in root.findall('.//PublicationType'):
            if elem.text:
                types.append(elem.text.strip())
        return types
    except Exception as exc:
        print(f'[!] Error retrieving publication types for PMID {pmid}: {exc}')
        return []
    finally:
        time.sleep(WAIT_TIME)


def publication_matches(pub_types):
    """Return True if any target publication type matches."""
    lower = [t.lower() for t in pub_types]
    for target in TARGET_PUB_TYPES:
        t_lower = target.lower()
        for t in lower:
            if t_lower in t:
                return True
    return False


def get_pdf_link(pmc_id):
    """Retrieve the PDF download URL for a given PMC article.
    Uses a custom User-Agent to avoid 403 errors and falls back to the
    legacy domain if the modern domain returns a 403. Checks the
    citation_pdf_url meta tag, then anchor text containing 'pdf', and
    finally any href ending with .pdf or containing '/pdf/'."""
    base_url = f'https://pmc.ncbi.nlm.nih.gov/articles/PMC{pmc_id}/'
    response = None
    try:
        response = requests.get(base_url, timeout=30, headers=HEADERS)
        response.raise_for_status()
    except requests.HTTPError:
        if response is not None and response.status_code == 403:
            alt_url = f'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC{pmc_id}/'
            try:
                response = requests.get(alt_url, timeout=30, headers=HEADERS)
                response.raise_for_status()
                base_url = alt_url
            except requests.RequestException:
                print(f'[!] Error accessing PMC{pmc_id}: 403 Forbidden on both domains')
                return None
        else:
            print(f'[!] Error accessing PMC{pmc_id}: {response.status_code if response else "HTTP error"}')
            return None
    except requests.RequestException as exc:
        print(f'[!] Error accessing PMC{pmc_id}: {exc}')
        return None
    soup = BeautifulSoup(response.text, 'html.parser')
    meta_tag = soup.find('meta', attrs={'name': 'citation_pdf_url'})
    if meta_tag and meta_tag.get('content'):
        return meta_tag['content']
    pdf_tag = soup.find('a', string=lambda text: text and 'pdf' in text.lower())
    if pdf_tag and pdf_tag.get('href'):
        href = pdf_tag['href']
        if href.startswith('http'):
            return href
        if href.startswith('/'):
            domain = 'https://' + base_url.split('/')[2]
            return domain + href
        return base_url + href
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.lower().endswith('.pdf') or '/pdf/' in href.lower():
            if href.startswith('http'):
                return href
            if href.startswith('/'):
                domain = 'https://' + base_url.split('/')[2]
                return domain + href
            return base_url + href
    return None


def download_pdf(pdf_url, filename):
    """Download and save a PDF from a URL using custom headers."""
    try:
        response = requests.get(pdf_url, timeout=60, headers=HEADERS)
        response.raise_for_status()
    except requests.RequestException as exc:
        print(f'[!] Failed to download {pdf_url}: {exc}')
        return
    with open(filename, 'wb') as fh:
        fh.write(response.content)


def run_download(csv_path):
    records = load_filtered_records(csv_path)
    print(f'Loaded {len(records)} candidate records from {csv_path}.')
    if not os.path.exists(DOWNLOAD_DIR):
        os.makedirs(DOWNLOAD_DIR)
    count = 0
    for pmid, pmc_id in records:
        pub_types = fetch_pub_types(pmid)
        if not pub_types or not publication_matches(pub_types):
            continue
        filename = os.path.join(DOWNLOAD_DIR, f'PMC{pmc_id}.pdf')
        if os.path.exists(filename):
            print(f'[✓] Already downloaded: PMC{pmc_id}')
            continue
        pdf_url = get_pdf_link(pmc_id)
        time.sleep(WAIT_TIME)
        if pdf_url:
            print(f'[*] Downloading PMC{pmc_id} -> {pdf_url}')
            download_pdf(pdf_url, filename)
            count += 1
        else:
            print(f'[x] PDF not found for PMC{pmc_id}')
        time.sleep(WAIT_TIME)
    print(f'Done. Downloaded {count} PDFs into "{DOWNLOAD_DIR}".')

# Uncomment below to run the download.
run_download(CSV_FILE)
# Out:
# Loaded 2176 candidate records from /content/csv-alzheimers-set.csv.
# [✓] Already downloaded: PMC12142702
# [✓] Already downloaded: PMC11970185
# [✓] Already downloaded: PMC12221384
# [✓] Already downloaded: PMC11839357
# [✓] Already downloaded: PMC11740155
# [x] PDF not found for PMC11813243
# [✓] Already downloaded: PMC11704942
# [✓] Already downloaded: PMC11677798
# [✓] Already downloaded: PMC11674444
# [✓] Already downloaded: PMC11695123
# [✓] Already downloaded: PMC11361754
# [✓] Already downloaded: PMC11676485
# [✓] Already downloaded: PMC11668837
# [✓] Already downloaded: PMC11663918
# [✓] Already downloaded: PMC11668108
# [✓] Already downloaded: PMC11657227
# [✓] Already downloaded: PMC11657461
# [✓] Already downloaded: PMC11641710
# [✓] Already downloaded: PMC11641728
# [✓] Already downloaded: PMC11641227
# [✓] Already downloaded: PMC11643865
# [✓] Already downloaded: PMC11643850
# [✓] Already downloaded: PMC11643945
# [✓] Already downloaded: PMC11643887
# [✓] Already downloaded: PMC11645901
# [✓] Already downloaded: PMC11726346
# [✓] Already downloaded: PMC11637393
# [✓] Already downloaded: PMC11631704
# [✓] Already downloaded: PMC11631881
# [✓] Already downloaded: PMC11630619
# [✓] Already downloaded: PMC11597442
# [✓] Already downloaded: PMC11596391
# [✓] Already downloaded: PMC11593565
# [✓] Already downloaded: PMC11594615
# [✓] Already downloaded: PMC11593474
# [✓] Already downloaded: PMC11593559
# [✓] Already downloaded: PMC11593898
# [✓] Already downloaded: PMC11591912
# [✓] Already downloaded: PMC11593771
# [✓] Already downloaded: PMC11587110
# [✓] Already downloaded: PMC11586835
# [✓] Already downloaded: PMC11585249
# [✓] Already downloaded: PMC11578756
# [✓] Already downloaded: PMC11733549
# [✓] Already downloaded: PMC11580643
# [✓] Already downloaded: PMC11579013
# [✓] Already downloaded: PMC11667534
# [✓] Already downloaded: PMC11573871
# [✓] Already downloaded: PMC11573826
# [✓] Already downloaded: PMC11573813
# [✓] Already downloaded: PMC11570530
# [✓] Already downloaded: PMC11560400
# [✓] Already downloaded: PMC11547905
# [✓] Already downloaded: PMC11547462
# [✓] Already downloaded: PMC11546674
# [✓] Already downloaded: PMC11545799
# [✓] Already downloaded: PMC11667501
# [✓] Already downloaded: PMC11541599
# [✓] Already downloaded: PMC11540257
# [✓] Already downloaded: PMC11539687
# [✓] Already downloaded: PMC11528462
# [✓] Already downloaded: PMC11524920
# [✓] Already downloaded: PMC11520896
# [✓] Already downloaded: PMC11510978
# [✓] Already downloaded: PMC11509913
# [✓] Already downloaded: PMC11508681
# [✓] Already downloaded: PMC11507169
# [✓] Already downloaded: PMC11506053
# [✓] Already downloaded: PMC11506381
# [✓] Already downloaded: PMC11506759
# [✓] Already downloaded: PMC11515500
# [✓] Already downloaded: PMC11515656
# [✓] Already downloaded: PMC11667530
# [✓] Already downloaded: PMC11491939
# [✓] Already downloaded: PMC11490654
# [✓] Already downloaded: PMC12312309
# [✓] Already downloaded: PMC11807374
# [✓] Already downloaded: PMC11511658
# [✓] Already downloaded: PMC11476806
# [✓] Already downloaded: PMC11451315
# [✓] Already downloaded: PMC11670881
# [✓] Already downloaded: PMC11471056
# [✓] Already downloaded: PMC11465679
# [✓] Already downloaded: PMC11465713
# [✓] Already downloaded: PMC11567808
# [✓] Already downloaded: PMC11663755
# [✓] Already downloaded: PMC11452425
# [✓] Already downloaded: PMC11602839
# [✓] Already downloaded: PMC11436400
# [✓] Already downloaded: PMC11436399
# [✓] Already downloaded: PMC11582148
# [✓] Already downloaded: PMC11434991
# [✓] Already downloaded: PMC11433989
# [✓] Already downloaded: PMC11432603
# [✓] Already downloaded: PMC11430190
# [✓] Already downloaded: PMC11439562
# [✓] Already downloaded: PMC11441869
# [✓] Already downloaded: PMC11429902
# [✓] Already downloaded: PMC11422111
# [✓] Already downloaded: PMC11567863
# [✓] Already downloaded: PMC11416944
# [✓] Already downloaded: PMC11421184
# [✓] Already downloaded: PMC11419515
# [✓] Already downloaded: PMC11407012
# [✓] Already downloaded: PMC11396831
# [✓] Already downloaded: PMC11397357
# [✓] Already downloaded: PMC11394828
# [✓] Already downloaded: PMC11395277
# [✓] Already downloaded: PMC11394293
# [✓] Already downloaded: PMC11386524
# [✓] Already downloaded: PMC11377238
# [✓] Already downloaded: PMC11485305
# [✓] Already downloaded: PMC11374656
# [✓] Already downloaded: PMC11367863
# [✓] Already downloaded: PMC11365738
# [✓] Already downloaded: PMC11354998
# [✓] Already downloaded: PMC11354293
# [✓] Already downloaded: PMC11354426
# [✓] Already downloaded: PMC11354546
# [✓] Already downloaded: PMC11348682
# [✓] Already downloaded: PMC11445594
# [✓] Already downloaded: PMC11341404
# [✓] Already downloaded: PMC11380290
# [✓] Already downloaded: PMC11340657
# [✓] Already downloaded: PMC11344989
# [✓] Already downloaded: PMC11485314
# [✓] Already downloaded: PMC11337902
# [✓] Already downloaded: PMC11335789
# [✓] Already downloaded: PMC11331696
# [✓] Already downloaded: PMC11485306
# [✓] Already downloaded: PMC11485391
# [✓] Already downloaded: PMC11317746
# [✓] Already downloaded: PMC11313713
# [✓] Already downloaded: PMC11314501
# [✓] Already downloaded: PMC11313984
# [✓] Already downloaded: PMC11311351
# [✓] Already downloaded: PMC11303073
# [✓] Already downloaded: PMC11298496
# [✓] Already downloaded: PMC11481234
# [✓] Already downloaded: PMC11485767
# [✓] Already downloaded: PMC11293045
# [✓] Already downloaded: PMC11324188
# [x] PDF not found for PMC11325121
# [✓] Already downloaded: PMC11287766
# [✓] Already downloaded: PMC11285646
# [✓] Already downloaded: PMC11288696
# [✓] Already downloaded: PMC11287986
# [✓] Already downloaded: PMC11349330
# [✓] Already downloaded: PMC11279795
# [✓] Already downloaded: PMC11277296
# [✓] Already downloaded: PMC11277458
# [✓] Already downloaded: PMC11272329
# [✓] Already downloaded: PMC11380317
# [✓] Already downloaded: PMC11269163
# [✓] Already downloaded: PMC11266110
# [✓] Already downloaded: PMC11266263
# [✓] Already downloaded: PMC11266440
# [✓] Already downloaded: PMC11266366
# [✓] Already downloaded: PMC11266256
# [✓] Already downloaded: PMC11665953
# [✓] Already downloaded: PMC11259573
# [✓] Already downloaded: PMC11362647
# [✓] Already downloaded: PMC11241624
# [✓] Already downloaded: PMC11241587
# [✓] Already downloaded: PMC11242057
# [✓] Already downloaded: PMC11235576
# [✓] Already downloaded: PMC11236904
# [✓] Already downloaded: PMC11314950
# [✓] Already downloaded: PMC11489248
# [✓] Already downloaded: PMC11258690
# [✓] Already downloaded: PMC11225352
# [✓] Already downloaded: PMC11224812
# [✓] Already downloaded: PMC11293203
# [✓] Already downloaded: PMC11220205
# [✓] Already downloaded: PMC11202106
# [✓] Already downloaded: PMC11336026
# [✓] Already downloaded: PMC11251480
# [✓] Already downloaded: PMC11258156
# [✓] Already downloaded: PMC11393286
# [✓] Already downloaded: PMC11199417
# [✓] Already downloaded: PMC11196435
# [✓] Already downloaded: PMC11200558
# [✓] Already downloaded: PMC11201198
# [✓] Already downloaded: PMC11204117
# [✓] Already downloaded: PMC11203520
# [✓] Already downloaded: PMC11203451
# [✓] Already downloaded: PMC11203688
# [✓] Already downloaded: PMC11544444
# [✓] Already downloaded: PMC11198029
# [✓] Already downloaded: PMC11892011
# [✓] Already downloaded: PMC11959453
# [✓] Already downloaded: PMC11294387
# [✓] Already downloaded: PMC11289344
# [✓] Already downloaded: PMC11289173
# [✓] Already downloaded: PMC11405261
# [✓] Already downloaded: PMC11188292
# [✓] Already downloaded: PMC11173861
# [✓] Already downloaded: PMC11173718
# [✓] Already downloaded: PMC11173253
# [✓] Already downloaded: PMC11167451
# [✓] Already downloaded: PMC11169267
# [✓] Already downloaded: PMC11348698
# [✓] Already downloaded: PMC11157928
# [✓] Already downloaded: PMC11307031
# [✓] Already downloaded: PMC11310295
# [✓] Already downloaded: PMC11488598
# [✓] Already downloaded: PMC11150578
# [✓] Already downloaded: PMC11164577
# [✓] Already downloaded: PMC11244742
# [✓] Already downloaded: PMC11182807
# [✓] Already downloaded: PMC11143595
# [✓] Already downloaded: PMC11135165
# [✓] Already downloaded: PMC11130822
# [✓] Already downloaded: PMC11130854
# [✓] Already downloaded: PMC11470851
# [✓] Already downloaded: PMC11122640
# [✓] Already downloaded: PMC11121409
# [✓] Already downloaded: PMC11121252
# [✓] Already downloaded: PMC11121732
# [✓] Already downloaded: PMC11119953
# [✓] Already downloaded: PMC11119296
# [✓] Already downloaded: PMC11107038
# [✓] Already downloaded: PMC11102828
# [✓] Already downloaded: PMC11378160
# [✓] Already downloaded: PMC11186782
# [✓] Already downloaded: PMC11191524
# [✓] Already downloaded: PMC11096505
# [✓] Already downloaded: PMC11094335
# [✓] Already downloaded: PMC11246816
# [✓] Already downloaded: PMC11091751
# [✓] Already downloaded: PMC11108785
# [✓] Already downloaded: PMC11092257
# [✓] Already downloaded: PMC11097689
# [✓] Already downloaded: PMC11085272
# [✓] Already downloaded: PMC11084463
# [✓] Already downloaded: PMC11084061
# [✓] Already downloaded: PMC11093050
# [✓] Already downloaded: PMC11077339
# [✓] Already downloaded: PMC11076839
# [✓] Already downloaded: PMC11483208
# [✓] Already downloaded: PMC11294028
# [✓] Already downloaded: PMC11077870
# [✓] Already downloaded: PMC11075320
# [✓] Already downloaded: PMC11074593
# [✓] Already downloaded: PMC11180860
# [✓] Already downloaded: PMC11061005
# [✓] Already downloaded: PMC11060991
# [✓] Already downloaded: PMC11057238
# [✓] Already downloaded: PMC11055304
# [✓] Already downloaded: PMC11055039
# [✓] Already downloaded: PMC11050334
# [✓] Already downloaded: PMC11049906
# [✓] Already downloaded: PMC11046958
# [✓] Already downloaded: PMC11045862
# [✓] Already downloaded: PMC11170295
# [✓] Already downloaded: PMC11029996
# [✓] Already downloaded: PMC11012623
# [✓] Already downloaded: PMC11055802
# [✓] Already downloaded: PMC11012190
# [✓] Already downloaded: PMC11012162
# [✓] Already downloaded: PMC11013124
# [✓] Already downloaded: PMC11012733
# [✓] Already downloaded: PMC11011709
# [✓] Already downloaded: PMC11015617
# [✓] Already downloaded: PMC11006915
# [✓] Already downloaded: PMC11088857
# [✓] Already downloaded: PMC11043025
# [✓] Already downloaded: PMC10991696
# [✓] Already downloaded: PMC11175821
# [✓] Already downloaded: PMC11556862
# [✓] Already downloaded: PMC11095417
# [✓] Already downloaded: PMC11254984
# [✓] Already downloaded: PMC11095473
# [✓] Already downloaded: PMC10980301
# [✓] Already downloaded: PMC11164642
# [✓] Already downloaded: PMC10975805
# [✓] Already downloaded: PMC10965877
# [✓] Already downloaded: PMC10944893
# [x] PDF not found for PMC11368525
# [✓] Already downloaded: PMC10931784
# [✓] Already downloaded: PMC10932469
# [✓] Already downloaded: PMC10925682
# [✓] Already downloaded: PMC11597006
# [x] PDF not found for PMC11098020
# [✓] Already downloaded: PMC11380223
# [✓] Already downloaded: PMC10920203
# [✓] Already downloaded: PMC11153287
# [✓] Already downloaded: PMC11587787
# [✓] Already downloaded: PMC10977351
# [✓] Already downloaded: PMC10977421
# [✓] Already downloaded: PMC11023809
# [✓] Already downloaded: PMC11107432
# [✓] Already downloaded: PMC10899454
# [✓] Already downloaded: PMC10899493
# [✓] Already downloaded: PMC10897030
# [✓] Already downloaded: PMC10884281
# [✓] Already downloaded: PMC10894607
# [✓] Already downloaded: PMC10892410
# [✓] Already downloaded: PMC10891920
# [✓] Already downloaded: PMC10888679
# [✓] Already downloaded: PMC10889119
# [✓] Already downloaded: PMC10943082
# [✓] Already downloaded: PMC10977380
# [✓] Already downloaded: PMC10890163
# [✓] Already downloaded: PMC10886970
# [✓] Already downloaded: PMC10881733
# [✓] Already downloaded: PMC11067698
# [✓] Already downloaded: PMC10884056
# [✓] Already downloaded: PMC10878147
# [✓] Already downloaded: PMC11090157
# [✓] Already downloaded: PMC11065606
# [✓] Already downloaded: PMC10867314
# [✓] Already downloaded: PMC11219096
# [✓] Already downloaded: PMC11001683
# [✓] Already downloaded: PMC10859247
# [✓] Already downloaded: PMC10856527
# [✓] Already downloaded: PMC10855047
# [✓] Already downloaded: PMC10854606
# [✓] Already downloaded: PMC11774317
# [✓] Already downloaded: PMC11306417
# [✓] Already downloaded: PMC10847178
# [✓] Already downloaded: PMC10838973
# [✓] Already downloaded: PMC10994193
# [✓] Already downloaded: PMC10830639
# [✓] Already downloaded: PMC10835811
# [✓] Already downloaded: PMC10824087
# [✓] Already downloaded: PMC10926277
# [✓] Already downloaded: PMC10815298
# [✓] Already downloaded: PMC10963923
# [✓] Already downloaded: PMC10813465
# [✓] Already downloaded: PMC10809445
# [✓] Already downloaded: PMC11032565
# [✓] Already downloaded: PMC11346399
# [✓] Already downloaded: PMC10804650
# [✓] Already downloaded: PMC10800801
# [✓] Already downloaded: PMC10800421
# [✓] Already downloaded: PMC10819522
# [✓] Already downloaded: PMC10816678
# [✓] Already downloaded: PMC10815728
# [✓] Already downloaded: PMC11233076
# [✓] Already downloaded: PMC11018519
# [✓] Already downloaded: PMC10802046
# [✓] Already downloaded: PMC10903104
# [✓] Already downloaded: PMC10800129
# [✓] Already downloaded: PMC10836579
# [✓] Already downloaded: PMC10778916
# [✓] Already downloaded: PMC10778631
# [✓] Already downloaded: PMC10779133
# [✓] Already downloaded: PMC11039429
# [✓] Already downloaded: PMC10790215
# [✓] Already downloaded: PMC10872319
# [✓] Already downloaded: PMC10758887
# [✓] Already downloaded: PMC10741896
# [✓] Already downloaded: PMC10741958
# [✓] Already downloaded: PMC10744068
# [✓] Already downloaded: PMC10744870
# [✓] Already downloaded: PMC10741927
# [✓] Already downloaded: PMC11236938
# [✓] Already downloaded: PMC10745513
# [✓] Already downloaded: PMC10722401
# [✓] Already downloaded: PMC11021265
# [✓] Already downloaded: PMC10733085
# [✓] Already downloaded: PMC10877737
# [✓] Already downloaded: PMC10716956
# [✓] Already downloaded: PMC10717316
# [✓] Already downloaded: PMC10710852
# [✓] Already downloaded: PMC11087435
# [✓] Already downloaded: PMC10789360
# [✓] Already downloaded: PMC10708332
# [✓] Already downloaded: PMC10704558
# [✓] Already downloaded: PMC10800127
# [✓] Already downloaded: PMC10694915
# [✓] Already downloaded: PMC10696485
# [✓] Already downloaded: PMC10960624
# [✓] Already downloaded: PMC11284712
# [✓] Already downloaded: PMC10683520
# [✓] Already downloaded: PMC10684725
# [✓] Already downloaded: PMC10688758
# [✓] Already downloaded: PMC10687886
# [✓] Already downloaded: PMC10655607
# [✓] Already downloaded: PMC10631450
# [✓] Already downloaded: PMC10683264
# [✓] Already downloaded: PMC10942903
# [✓] Already downloaded: PMC10724064
# [✓] Already downloaded: PMC10676341
# [✓] Already downloaded: PMC10674591
# [✓] Already downloaded: PMC10673433
# [✓] Already downloaded: PMC10671406
# [✓] Already downloaded: PMC10671071
# [✓] Already downloaded: PMC10666448
# [✓] Already downloaded: PMC10906067
# [✓] Already downloaded: PMC10630722
# [✓] Already downloaded: PMC10680548
# [✓] Already downloaded: PMC10652426
# [✓] Already downloaded: PMC10794000
# [✓] Already downloaded: PMC10641152
# [✓] Already downloaded: PMC10650229
# [✓] Already downloaded: PMC10649239
# [✓] Already downloaded: PMC10789674
# [✓] Already downloaded: PMC11262040
# [✓] Already downloaded: PMC11074035
# [✓] Already downloaded: PMC11043177
# [✓] Already downloaded: PMC10625913
# [✓] Already downloaded: PMC10631445
# [✓] Already downloaded: PMC11505376
# [x] PDF not found for PMC10641860
# [✓] Already downloaded: PMC10741341
# [✓] Already downloaded: PMC10616904
# [✓] Already downloaded: PMC10916451
# [*] Downloading PMC10615483 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10615483/pdf/medi-102-e34503.pdf
# [*] Downloading PMC10615487 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10615487/pdf/medi-102-e35669.pdf
# [*] Downloading PMC10617290 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10617290/pdf/10.1177_03946320231209839.pdf
# [*] Downloading PMC10607039 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10607039/pdf/ijms-24-15481.pdf
# [*] Downloading PMC10609179 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10609179/pdf/molecules-28-07150.pdf
# [*] Downloading PMC10609487 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10609487/pdf/molecules-28-07117.pdf
# [*] Downloading PMC10609799 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10609799/pdf/nutrients-15-04363.pdf
# [*] Downloading PMC10604144 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10604144/pdf/biomolecules-13-01446.pdf
# [*] Downloading PMC10734664 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10734664/pdf/nihms-1949684.pdf
# [*] Downloading PMC11103249 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11103249/pdf/nihms-1986263.pdf
# [*] Downloading PMC10586905 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10586905/pdf/BN2023-8825358.pdf
# [*] Downloading PMC10585369 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10585369/pdf/fcimb-13-1282431.pdf
# [*] Downloading PMC10625460 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10625460/pdf/nihms-1937977.pdf
# [*] Downloading PMC10594166 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10594166/pdf/S2056472423005793a.pdf
# [*] Downloading PMC11758986 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11758986/pdf/nihms-2046151.pdf
# [*] Downloading PMC10573645 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10573645/pdf/jcm-12-06190.pdf
# [*] Downloading PMC10578107 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10578107/pdf/ijms-24-14499.pdf
# [*] Downloading PMC10770002 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10770002/pdf/415_2023_Article_12033.pdf
# [*] Downloading PMC10562987 -> https://pmc.ncbi.nlm.nih.gov/articles/instance/10562987/bin/jamaneurol-e233490-s001.pdf
# [*] Downloading PMC10557994 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10557994/pdf/cia-18-1629.pdf
# [*] Downloading PMC10741308 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10741308/pdf/jad-96-jad230467.pdf
# [*] Downloading PMC10558228 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10558228/pdf/ijmm-52-5-05314.pdf
# [*] Downloading PMC11473583 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11473583/pdf/11065_2023_Article_9607.pdf
# [*] Downloading PMC10543744 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10543744/pdf/fnagi-15-1241224.pdf
# [*] Downloading PMC10547150 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10547150/pdf/pone.0292180.pdf
# [*] Downloading PMC10544555 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10544555/pdf/12929_2023_Article_976.pdf
# [*] Downloading PMC11934145 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11934145/pdf/nihms-2046464.pdf
# [*] Downloading PMC10535911 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10535911/pdf/molecules-28-06501.pdf
# [*] Downloading PMC10531537 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10531537/pdf/ijms-24-14177.pdf
# [*] Downloading PMC10531090 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10531090/pdf/ijms-24-13900.pdf
# [*] Downloading PMC10526757 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10526757/pdf/biomolecules-13-01388.pdf
# [*] Downloading PMC11001507 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11001507/pdf/ars.2023.0245.pdf
# [*] Downloading PMC10580905 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10580905/pdf/iai.00437-22.pdf
# [*] Downloading PMC11671221 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11671221/pdf/discoveries-11-173.pdf
# [*] Downloading PMC10516255 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10516255/pdf/cureus-0015-00000043984.pdf
# [*] Downloading PMC10796582 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10796582/pdf/11906_2023_Article_1266.pdf
# [*] Downloading PMC10840823 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10840823/pdf/nihms-1919199.pdf
# [*] Downloading PMC10578497 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10578497/pdf/nihms-1927464.pdf
# [*] Downloading PMC10582128 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10582128/pdf/40265_2023_Article_1938.pdf
# [*] Downloading PMC11407742 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11407742/pdf/10571_2023_Article_1408.pdf
# [*] Downloading PMC10507596 -> https://pmc.ncbi.nlm.nih.gov/articles/instance/10507596/bin/jamaneurol-e233240-s001.pdf
# [*] Downloading PMC10581564 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10581564/pdf/NRR-19-512.pdf
# [*] Downloading PMC10500921 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10500921/pdf/40001_2023_Article_1337.pdf
# [*] Downloading PMC10498335 -> https://cran.r-project.org/web/packages/coxme/coxme.pdf
# [*] Downloading PMC10841343 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10841343/pdf/ALZ-20-652.pdf
# [*] Downloading PMC11235913 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11235913/pdf/ENE-31-e16049.pdf
# [*] Downloading PMC10664792 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10664792/pdf/wad-37-290.pdf
# [*] Downloading PMC10643494 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10643494/pdf/11357_2023_Article_913.pdf
# [*] Downloading PMC10490073 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10490073/pdf/nutrients-15-03706.pdf
# [*] Downloading PMC10487553 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10487553/pdf/ijms-24-13067.pdf
# [*] Downloading PMC10488399 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10488399/pdf/jcm-12-05497.pdf
# [*] Downloading PMC10600312 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10600312/pdf/40266_2023_Article_1065.pdf
# [*] Downloading PMC10875739 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10875739/pdf/nihms-1960645.pdf
# [*] Downloading PMC11138351 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11138351/pdf/main.pdf
# [*] Downloading PMC10570495 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10570495/pdf/BRB3-13-e3207.pdf
# [*] Downloading PMC10469775 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10469775/pdf/fpsyt-14-1158546.pdf
# [*] Downloading PMC10473157 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10473157/pdf/adr-7-adr230025.pdf
# [*] Downloading PMC10624490 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10624490/pdf/WNL-2023-000517.pdf
# [*] Downloading PMC11337690 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11337690/pdf/CN-22-2157.pdf
# [*] Downloading PMC10573141 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10573141/pdf/WNL-2023-000459.pdf
# [*] Downloading PMC10916995 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10916995/pdf/ALZ-20-25.pdf
# [*] Downloading PMC10529332 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10529332/pdf/nihms-1921134.pdf
# [*] Downloading PMC10454935 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10454935/pdf/ijms-24-12639.pdf
# [*] Downloading PMC10457886 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10457886/pdf/sports-11-00149.pdf
# [*] Downloading PMC10433620 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10433620/pdf/12987_2023_Article_464.pdf
# [*] Downloading PMC10433666 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10433666/pdf/13643_2023_Article_2301.pdf
# [*] Downloading PMC10773532 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10773532/pdf/nihms-1956329.pdf
# [*] Downloading PMC10422028 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10422028/pdf/fmed-10-1159316.pdf
# [*] Downloading PMC10420887 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10420887/pdf/nutrients-15-03454.pdf
# [*] Downloading PMC10421033 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10421033/pdf/nutrients-15-03428.pdf
# [*] Downloading PMC10420906 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10420906/pdf/molecules-28-05824.pdf
# [*] Downloading PMC10420665 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10420665/pdf/molecules-28-05716.pdf
# [*] Downloading PMC10420307 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10420307/pdf/molecules-28-05624.pdf
# [*] Downloading PMC10419627 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10419627/pdf/ijms-24-12513.pdf
# [*] Downloading PMC10420049 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10420049/pdf/ijms-24-12498.pdf
# [*] Downloading PMC10419704 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10419704/pdf/ijms-24-12486.pdf
# [*] Downloading PMC10418374 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10418374/pdf/ijms-24-12293.pdf
# [*] Downloading PMC10485904 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10485904/pdf/cn3c00486.pdf
# [*] Downloading PMC10980893 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10980893/pdf/main.pdf
# [*] Downloading PMC10405778 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10405778/pdf/CD011022.pdf
# [*] Downloading PMC10400716 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10400716/pdf/fneur-14-1185721.pdf
# [*] Downloading PMC10389278 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10389278/pdf/fneur-14-1209205.pdf
# [*] Downloading PMC10385921 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10385921/pdf/12891_2023_Article_6721.pdf
# [*] Downloading PMC10380291 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10380291/pdf/ijms-24-11780.pdf
# [*] Downloading PMC10380685 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10380685/pdf/ijms-24-11450.pdf
# [*] Downloading PMC10379573 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10379573/pdf/ijms-24-11301.pdf
# [*] Downloading PMC10379298 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10379298/pdf/ijms-24-11296.pdf
# [*] Downloading PMC10379780 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10379780/pdf/ijms-24-11275.pdf
# [*] Downloading PMC10377475 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10377475/pdf/brainsci-13-01061.pdf
# [*] Downloading PMC10377702 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10377702/pdf/brainsci-13-00981.pdf
# [*] Downloading PMC10663011 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10663011/pdf/WNL-2023-001629.pdf
# [*] Downloading PMC10457280 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10457280/pdf/13311_2023_Article_1408.pdf
# [*] Downloading PMC10457266 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10457266/pdf/13311_2023_Article_1405.pdf
# [*] Downloading PMC10366907 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10366907/pdf/geriatrics-08-00075.pdf
# [*] Downloading PMC10357125 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10357125/pdf/adr-7-adr220084.pdf
# [*] Downloading PMC10363705 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10363705/pdf/rstb.2022.0230.pdf
# [*] Downloading PMC10362671 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10362671/pdf/13195_2023_Article_1268.pdf
# [*] Downloading PMC10439019 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10439019/pdf/40263_2023_Article_1021.pdf
# [!] Error accessing PMC10352578: HTTP error
# [x] PDF not found for PMC10352578
# [*] Downloading PMC10351420 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10351420/pdf/fendo-14-1217730.pdf
# [*] Downloading PMC10796101 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10796101/pdf/ad-15-1-43.pdf
# [*] Downloading PMC10530125 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10530125/pdf/nihms-1917790.pdf
# [*] Downloading PMC10336689 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10336689/pdf/main.pdf
# [*] Downloading PMC10347110 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10347110/pdf/nutrients-15-03059.pdf
# [*] Downloading PMC10342514 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10342514/pdf/ijms-24-11191.pdf
# [*] Downloading PMC10342267 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10342267/pdf/ijms-24-11086.pdf
# [*] Downloading PMC10341783 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10341783/pdf/ijms-24-10717.pdf
# [*] Downloading PMC10341681 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10341681/pdf/ijms-24-10505.pdf
# [*] Downloading PMC10336149 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10336149/pdf/41392_2023_Article_1486.pdf
# [*] Downloading PMC10329479 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10329479/pdf/cureus-0015-00000040138.pdf
# [*] Downloading PMC10318422 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10318422/pdf/TRC2-9-e12402.pdf
# [*] Downloading PMC10318843 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10318843/pdf/13024_2023_Article_636.pdf
# [*] Downloading PMC10312383 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10312383/pdf/dddt-17-1907.pdf
# [*] Downloading PMC10338203 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10338203/pdf/main.pdf
# [*] Downloading PMC10310315 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10310315/pdf/CD013388.pdf
# [*] Downloading PMC10306158 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10306158/pdf/fcad175.pdf
# [*] Downloading PMC10328538 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10328538/pdf/coneu-36-264.pdf
# [*] Downloading PMC10306194 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10306194/pdf/pone.0286887.pdf
# [*] Downloading PMC10302352 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10302352/pdf/molecules-28-04797.pdf
# [*] Downloading PMC10299122 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10299122/pdf/ijms-24-10176.pdf
# [*] Downloading PMC10298520 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10298520/pdf/ijms-24-09846.pdf
# [*] Downloading PMC10294814 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10294814/pdf/antioxidants-12-01282.pdf
# [*] Downloading PMC10296091 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10296091/pdf/biomolecules-13-00967.pdf
# [*] Downloading PMC10296707 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10296707/pdf/biomolecules-13-00927.pdf
# [*] Downloading PMC11284722 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11284722/pdf/CN-22-1621.pdf
# [*] Downloading PMC10448838 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10448838/pdf/nihms-1913035.pdf
# [*] Downloading PMC10473097 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10473097/pdf/jad-94-jad230004.pdf
# [*] Downloading PMC10580344 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10580344/pdf/CNS-29-3160.pdf
# [*] Downloading PMC10314118 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10314118/pdf/main.pdf
# [*] Downloading PMC10374790 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10374790/pdf/40263_2023_Article_1017.pdf
# [*] Downloading PMC10300519 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10300519/pdf/dc222539.pdf
# [*] Downloading PMC10473113 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10473113/pdf/jpd-13-jpd225116.pdf
# [*] Downloading PMC10272527 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10272527/pdf/fimmu-14-1207641.pdf
# [*] Downloading PMC10270324 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10270324/pdf/fphar-14-1190604.pdf
# [*] Downloading PMC10276371 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10276371/pdf/12987_2023_Article_447.pdf
# [*] Downloading PMC11285555 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11285555/pdf/frdem-02-1199319.pdf
# [*] Downloading PMC10259075 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10259075/pdf/adr-7-adr220115.pdf
# [*] Downloading PMC10258618 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10258618/pdf/touchendo-19-1-016.pdf
# [*] Downloading PMC10261112 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10261112/pdf/41598_2023_Article_36604.pdf
# [*] Downloading PMC10357157 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10357157/pdf/jad-94-jad230231.pdf
# [*] Downloading PMC10254448 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10254448/pdf/molecules-28-04525.pdf
# [*] Downloading PMC10251882 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10251882/pdf/cancers-15-02972.pdf
# [*] Downloading PMC10252401 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10252401/pdf/cells-12-01478.pdf
# [*] Downloading PMC10249679 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10249679/pdf/nihms-1904357.pdf
# [*] Downloading PMC10957696 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10957696/pdf/11011_2023_Article_1247.pdf
# [*] Downloading PMC10629981 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10629981/pdf/awad188.pdf
# [*] Downloading PMC10228832 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10228832/pdf/fnins-17-1127065.pdf
# [*] Downloading PMC10230772 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10230772/pdf/12883_2023_Article_3191.pdf
# [*] Downloading PMC10210353 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10210353/pdf/DAD2-15-e12421.pdf
# [*] Downloading PMC10211371 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10211371/pdf/ijn-18-2737.pdf
# [*] Downloading PMC10357178 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10357178/pdf/jad-94-jad230406.pdf
# [*] Downloading PMC10401104 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10401104/pdf/CNS-29-2413.pdf
# [*] Downloading PMC10224607 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10224607/pdf/12967_2023_Article_4220.pdf
# [*] Downloading PMC10220548 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10220548/pdf/nutrients-15-02270.pdf
# [*] Downloading PMC10218422 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10218422/pdf/ijms-24-08827.pdf
# [*] Downloading PMC10216730 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10216730/pdf/biomedicines-11-01387.pdf
# [*] Downloading PMC10216254 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10216254/pdf/biomolecules-13-00747.pdf
# [*] Downloading PMC10404567 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10404567/pdf/11154_2023_Article_9807.pdf
# [*] Downloading PMC10207692 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10207692/pdf/13195_2023_Article_1238.pdf
# [*] Downloading PMC10208513 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10208513/pdf/pone.0285346.pdf
# [*] Downloading PMC10201752 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10201752/pdf/12874_2023_Article_1936.pdf
# [*] Downloading PMC10194838 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10194838/pdf/fnins-17-1147177.pdf
# [*] Downloading PMC10196238 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10196238/pdf/fnagi-15-1169499.pdf
# [*] Downloading PMC10336852 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10336852/pdf/nihms-1913741.pdf
# [*] Downloading PMC10473110 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10473110/pdf/jad-94-jad221298.pdf
# [*] Downloading PMC10137097 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10137097/pdf/cells-12-01193.pdf
# [*] Downloading PMC10136077 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10136077/pdf/biomedicines-11-01161.pdf
# [*] Downloading PMC10136066 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10136066/pdf/biomedicines-11-00994.pdf
# [*] Downloading PMC10136110 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10136110/pdf/biomolecules-13-00666.pdf
# [*] Downloading PMC10357189 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10357189/pdf/jad-93-jad221125.pdf
# [*] Downloading PMC10169719 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10169719/pdf/fnagi-15-1051809.pdf
# [*] Downloading PMC10174250 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10174250/pdf/fneur-14-1145939.pdf
# [*] Downloading PMC10178921 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10178921/pdf/ijms-24-07960.pdf
# [*] Downloading PMC10176668 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10176668/pdf/40035_2023_Article_358.pdf
# [*] Downloading PMC10173947 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10173947/pdf/40263_2023_Article_1007.pdf
# [*] Downloading PMC10169152 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10169152/pdf/40520_2023_Article_2409.pdf
# [*] Downloading PMC10154713 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10154713/pdf/fcad085.pdf
# [*] Downloading PMC10150074 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10150074/pdf/fneur-14-1103052.pdf
# [*] Downloading PMC10457253 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10457253/pdf/13311_2023_Article_1379.pdf
# [*] Downloading PMC10258880 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10258880/pdf/jad-93-jad221194.pdf
# [*] Downloading PMC10133458 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10133458/pdf/fnins-17-1154180.pdf
# [*] Downloading PMC10352876 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10352876/pdf/CNS-29-2045.pdf
# [*] Downloading PMC10127103 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10127103/pdf/fcimb-13-1103189.pdf
# [*] Downloading PMC10145943 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10145943/pdf/nutrients-15-01913.pdf
# [*] Downloading PMC10142927 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10142927/pdf/ijms-24-07652.pdf
# [*] Downloading PMC10287562 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10287562/pdf/41591_2023_Article_2326.pdf
# [*] Downloading PMC10493651 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10493651/pdf/CNS-29-2912.pdf
# [*] Downloading PMC10264050 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10264050/pdf/WNL-2023-000205.pdf
# [*] Downloading PMC10457276 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10457276/pdf/13311_2023_Article_1376.pdf
# [*] Downloading PMC10104285 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10104285/pdf/pone.0282590.pdf
# [*] Downloading PMC10103468 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10103468/pdf/40035_2023_Article_350.pdf
# [*] Downloading PMC10096917 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10096917/pdf/nutrients-15-01558.pdf
# [*] Downloading PMC10095144 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10095144/pdf/ijms-24-06566.pdf
# [*] Downloading PMC10094282 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10094282/pdf/ijms-24-06278.pdf
# [*] Downloading PMC10091330 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10091330/pdf/12883_2023_Article_3176.pdf
# [*] Downloading PMC10134019 -> https://population.un.org/wpp/publications/files/key_findings_wpp_2015.pdf
# [!] Failed to download https://population.un.org/wpp/publications/files/key_findings_wpp_2015.pdf: 404 Client Error: The requested content does not exist. for url: https://population.un.org/wpp/publications/files/key_findings_wpp_2015.pdf
# [*] Downloading PMC10102054 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10102054/pdf/213_2023_Article_6362.pdf
# [*] Downloading PMC10333383 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10333383/pdf/10571_2023_Article_1344.pdf
# [*] Downloading PMC10400530 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10400530/pdf/11357_2023_Article_782.pdf
# [*] Downloading PMC10195935 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10195935/pdf/40120_2023_Article_467.pdf
# [*] Downloading PMC10330155 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10330155/pdf/nihms-1894746.pdf
# [*] Downloading PMC10374694 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10374694/pdf/702_2023_Article_2618.pdf
# [*] Downloading PMC10070452 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10070452/pdf/41598_2023_Article_32515.pdf
# [*] Downloading PMC10041984 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10041984/pdf/ndt-19-647.pdf
# [*] Downloading PMC10059971 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10059971/pdf/molecules-28-02636.pdf
# [*] Downloading PMC10054164 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10054164/pdf/metabolites-13-00438.pdf
# [*] Downloading PMC10049047 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10049047/pdf/ijms-24-05250.pdf
# [*] Downloading PMC10046499 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10046499/pdf/biomolecules-13-00549.pdf
# [*] Downloading PMC10053682 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10053682/pdf/marinedrugs-21-00144.pdf
# [*] Downloading PMC10041788 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10041788/pdf/13195_2023_Article_1214.pdf
# [*] Downloading PMC10186239 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10186239/pdf/WNL-2023-000066.pdf
# [*] Downloading PMC10042350 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10042350/pdf/pone.0283449.pdf
# [*] Downloading PMC10369478 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10369478/pdf/nihms-1907552.pdf
# [*] Downloading PMC10038173 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10038173/pdf/cureus-0015-00000036634.pdf
# [*] Downloading PMC10123871 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10123871/pdf/nihms-1887859.pdf
# [*] Downloading PMC11214152 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11214152/pdf/nihms-1999118.pdf
# [*] Downloading PMC10028084 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10028084/pdf/fnagi-15-1124710.pdf
# [*] Downloading PMC10028478 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10028478/pdf/fphar-14-1053680.pdf
# [*] Downloading PMC10514243 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10514243/pdf/nihms-1905707.pdf
# [*] Downloading PMC10190566 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10190566/pdf/NBT2-17-154.pdf
# [*] Downloading PMC10032479 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10032479/pdf/pone.0281784.pdf
# [*] Downloading PMC12315912 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC12315912/pdf/nihms-2095687.pdf
# [*] Downloading PMC10564940 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10564940/pdf/41433_2023_Article_2483.pdf
# [*] Downloading PMC10014812 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10014812/pdf/fnagi-15-1134775.pdf
# [*] Downloading PMC10020338 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10020338/pdf/fnagi-15-1103039.pdf
# [*] Downloading PMC10014555 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10014555/pdf/fcell-10-1047094.pdf
# [*] Downloading PMC11166762 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11166762/pdf/11065_2023_Article_9584.pdf
# [*] Downloading PMC10022272 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10022272/pdf/13024_2023_Article_605.pdf
# [*] Downloading PMC10286587 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10286587/pdf/CN-21-1081.pdf
# [*] Downloading PMC10011110 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10011110/pdf/fnut-10-1139558.pdf
# [*] Downloading PMC10286584 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10286584/pdf/CN-21-1273.pdf
# [*] Downloading PMC10005336 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10005336/pdf/molecules-28-02336.pdf
# [*] Downloading PMC10002567 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10002567/pdf/ijms-24-04643.pdf
# [*] Downloading PMC10003045 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10003045/pdf/ijms-24-04399.pdf
# [*] Downloading PMC10001833 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10001833/pdf/ijms-24-04297.pdf
# [*] Downloading PMC10001413 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10001413/pdf/cells-12-00763.pdf
# [*] Downloading PMC9987204 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9987204/pdf/CPJ-2022-200123.pdf
# [*] Downloading PMC10465385 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10465385/pdf/406_2023_Article_1571.pdf
# [*] Downloading PMC9968124 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9968124/pdf/sensors-23-02145.pdf
# [*] Downloading PMC9972756 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9972756/pdf/13195_2023_Article_1169.pdf
# [*] Downloading PMC10115503 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10115503/pdf/WNL-2023-000012.pdf
# [*] Downloading PMC9965316 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9965316/pdf/nutrients-15-01000.pdf
# [*] Downloading PMC9964432 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9964432/pdf/ijms-24-03205.pdf
# [*] Downloading PMC9953539 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9953539/pdf/biomolecules-13-00309.pdf
# [*] Downloading PMC10227921 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10227921/pdf/CN-21-777.pdf
# [*] Downloading PMC9941033 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9941033/pdf/cureus-0015-00000033982.pdf
# [*] Downloading PMC10363181 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10363181/pdf/nihms-1874796.pdf
# [*] Downloading PMC9939698 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9939698/pdf/fncom-17-1038636.pdf
# [*] Downloading PMC9938630 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9938630/pdf/main.pdf
# [*] Downloading PMC10175976 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10175976/pdf/CTS-16-810.pdf
# [*] Downloading PMC10473139 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10473139/pdf/jad-94-jad221081.pdf
# [*] Downloading PMC11578022 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11578022/pdf/PSYG-23-512.pdf
# [*] Downloading PMC9920976 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9920976/pdf/molecules-28-01486.pdf
# [*] Downloading PMC9921752 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9921752/pdf/molecules-28-01283.pdf
# [*] Downloading PMC9921523 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9921523/pdf/molecules-28-01084.pdf
# [*] Downloading PMC9917989 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9917989/pdf/ijms-24-03022.pdf
# [*] Downloading PMC9916953 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9916953/pdf/ijms-24-02381.pdf
# [*] Downloading PMC9907029 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9907029/pdf/fneur-13-1063598.pdf
# [*] Downloading PMC10288481 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10288481/pdf/bjp-45-03-286.pdf
# [*] Downloading PMC9909060 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9909060/pdf/10.1177_15347354221150787.pdf
# [*] Downloading PMC10109527 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10109527/pdf/ACN3-10-520.pdf
# [*] Downloading PMC10154469 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10154469/pdf/NRR-18-1679.pdf
# [*] Downloading PMC10275297 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10275297/pdf/nihms-1873229.pdf
# [*] Downloading PMC10556370 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10556370/pdf/CN-21-2097.pdf
# [*] Downloading PMC10232284 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10232284/pdf/awad024.pdf
# [*] Downloading PMC9896226 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9896226/pdf/bmjopen-2022-064169.pdf
# [*] Downloading PMC9872519 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9872519/pdf/fnagi-14-1077732.pdf
# [*] Downloading PMC9879258 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9879258/pdf/40035_2023_Article_336.pdf
# [*] Downloading PMC9878977 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9878977/pdf/CD012144.pdf
# [*] Downloading PMC9939975 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9939975/pdf/problendo-68-13148.pdf
# [*] Downloading PMC9842041 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9842041/pdf/BTM2-8-e10367.pdf
# [*] Downloading PMC10041421 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10041421/pdf/jad-92-jad221189.pdf
# [*] Downloading PMC10041442 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10041442/pdf/jad-92-jad220871.pdf
# [*] Downloading PMC9866349 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9866349/pdf/nutrients-15-00386.pdf
# [*] Downloading PMC9866105 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9866105/pdf/life-13-00173.pdf
# [*] Downloading PMC9863713 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9863713/pdf/ijms-24-01717.pdf
# [*] Downloading PMC9856690 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9856690/pdf/cells-12-00252.pdf
# [*] Downloading PMC9856546 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9856546/pdf/brainsci-13-00153.pdf
# [*] Downloading PMC9867307 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9867307/pdf/marinedrugs-21-00043.pdf
# [*] Downloading PMC9844333 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9844333/pdf/neurolint-15-00002.pdf
# [*] Downloading PMC11878108 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC11878108/pdf/nihms-1850531.pdf
# [*] Downloading PMC9837011 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9837011/pdf/10103_2022_Article_3692.pdf
# [*] Downloading PMC9976038 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9976038/pdf/S003329172200397Xa.pdf
# [*] Downloading PMC9983432 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9983432/pdf/nihms-1868826.pdf
# [*] Downloading PMC9822395 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9822395/pdf/molecules-28-00080.pdf
# [*] Downloading PMC9822486 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9822486/pdf/molecules-28-00002.pdf
# [*] Downloading PMC9820882 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9820882/pdf/ijms-24-00823.pdf
# [*] Downloading PMC9820606 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9820606/pdf/ijms-24-00142.pdf
# [*] Downloading PMC9820561 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9820561/pdf/ijms-24-00087.pdf
# [*] Downloading PMC9818415 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9818415/pdf/cells-12-00131.pdf
# [*] Downloading PMC10174131 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10174131/pdf/AnnalsATS.202209-797OC.pdf
# [*] Downloading PMC9800994 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9800994/pdf/fendo-13-1074911.pdf
# [*] Downloading PMC9803890 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9803890/pdf/210_2022_Article_2372.pdf
# [*] Downloading PMC10394955 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10394955/pdf/10.1177_08919887221149152.pdf
# [*] Downloading PMC9847612 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9847612/pdf/BRB3-13-e2850.pdf
# [*] Downloading PMC9771092 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9771092/pdf/cureus-0014-00000031710.pdf
# [*] Downloading PMC10324337 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10324337/pdf/CN-21-1421.pdf
# [*] Downloading PMC9986694 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9986694/pdf/jad-91-jad220724.pdf
# [*] Downloading PMC9781052 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9781052/pdf/molecules-27-09043.pdf
# [*] Downloading PMC9783609 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9783609/pdf/molecules-27-08719.pdf
# [*] Downloading PMC9779379 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9779379/pdf/ijms-23-15811.pdf
# [*] Downloading PMC9768996 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9768996/pdf/13195_2022_Article_1124.pdf
# [*] Downloading PMC9870453 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9870453/pdf/nihms-1851193.pdf
# [*] Downloading PMC9747761 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9747761/pdf/fneur-13-1018027.pdf
# [*] Downloading PMC9751343 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9751343/pdf/fnhum-16-899814.pdf
# [*] Downloading PMC10105523 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10105523/pdf/nihms-1890166.pdf
# [*] Downloading PMC9747539 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9747539/pdf/40266_2022_Article_992.pdf
# [*] Downloading PMC9737775 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9737775/pdf/nutrients-14-05132.pdf
# [*] Downloading PMC9739023 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9739023/pdf/nutrients-14-05003.pdf
# [*] Downloading PMC9739281 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9739281/pdf/ijms-23-15320.pdf
# [*] Downloading PMC9738397 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9738397/pdf/ijms-23-15238.pdf
# [*] Downloading PMC9736131 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9736131/pdf/ijms-23-14835.pdf
# ...
# [*] Downloading PMC7683109 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7683109/pdf/BMRI2020-1034325.pdf
# [*] Downloading PMC8379190 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC8379190/pdf/41401_2020_Article_565.pdf
# [*] Downloading PMC7760745 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7760745/pdf/cells-09-02556.pdf
# [*] Downloading PMC7761499 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7761499/pdf/jcm-09-03840.pdf
# [*] Downloading PMC7963803 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7963803/pdf/main.pdf
# [*] Downloading PMC7690210 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7690210/pdf/12974_2020_Article_2024.pdf
# [*] Downloading PMC7699687 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7699687/pdf/molecules-25-05439.pdf
# [*] Downloading PMC7699472 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7699472/pdf/ijms-21-08767.pdf
# [*] Downloading PMC7699542 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7699542/pdf/ijms-21-08751.pdf
# [*] Downloading PMC10049459 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10049459/pdf/nihms-1673513.pdf
# [*] Downloading PMC9185776 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9185776/pdf/CN-19-2205.pdf
# [*] Downloading PMC7986114 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7986114/pdf/CMDC-16-767.pdf
# [*] Downloading PMC7929960 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7929960/pdf/12017_2020_Article_8629.pdf
# [*] Downloading PMC7698208 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7698208/pdf/ijms-21-08637.pdf
# [*] Downloading PMC7696575 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7696575/pdf/nutrients-12-03523.pdf
# [*] Downloading PMC7674095 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7674095/pdf/bmjopen-2020-038971.pdf
# [*] Downloading PMC7697162 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7697162/pdf/molecules-25-05294.pdf
# [*] Downloading PMC7746393 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7746393/pdf/aging-12-103933.pdf
# [*] Downloading PMC7482623 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7482623/pdf/peerj-08-9845.pdf
# [*] Downloading PMC8094738 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC8094738/pdf/CD009178.pdf
# [*] Downloading PMC7696081 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7696081/pdf/nutrients-12-03458.pdf
# [*] Downloading PMC7696280 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7696280/pdf/molecules-25-05245.pdf
# [*] Downloading PMC7666424 -> https://pmc.ncbi.nlm.nih.gov/articles/instance/7666424/bin/jamanetwopen-e2025515-s001.pdf
# [*] Downloading PMC8116411 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC8116411/pdf/13311_2020_Article_959.pdf
# [*] Downloading PMC8033975 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC8033975/pdf/CN-19-136.pdf
# [*] Downloading PMC7749085 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7749085/pdf/nihms-1640102.pdf
# [*] Downloading PMC7664397 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7664397/pdf/ijms-21-08335.pdf
# [*] Downloading PMC7664636 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7664636/pdf/molecules-25-05188.pdf
# [*] Downloading PMC7664437 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7664437/pdf/molecules-25-05186.pdf
# [*] Downloading PMC7650148 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7650148/pdf/12906_2020_Article_3102.pdf
# [*] Downloading PMC7642307 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7642307/pdf/cs-134-cs20200899.pdf
# [*] Downloading PMC7582079 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7582079/pdf/OMCL2020-3534570.pdf
# [*] Downloading PMC7597002 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7597002/pdf/13195_2020_Article_703.pdf
# [*] Downloading PMC7561408 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7561408/pdf/fimmu-11-573256.pdf
# [*] Downloading PMC7693759 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7693759/pdf/cells-09-02350.pdf
# [*] Downloading PMC8116360 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC8116360/pdf/13311_2020_Article_954.pdf
# [*] Downloading PMC7690401 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7690401/pdf/biomedicines-08-00446.pdf
# [*] Downloading PMC7587961 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7587961/pdf/molecules-25-04866.pdf
# [*] Downloading PMC7586271 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7586271/pdf/10.1177_2515690X20957225.pdf
# [*] Downloading PMC7606404 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7606404/pdf/40120_2020_Article_218.pdf
# [*] Downloading PMC7589751 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7589751/pdf/ijms-21-07660.pdf
# [*] Downloading PMC7571527 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7571527/pdf/12035_2020_Article_2177.pdf
# [*] Downloading PMC7880246 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7880246/pdf/nihms-1666597.pdf
# [*] Downloading PMC7589740 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7589740/pdf/ijms-21-07586.pdf
# [*] Downloading PMC7600778 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7600778/pdf/ijerph-17-07439.pdf
# [*] Downloading PMC7561468 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7561468/pdf/40256_2020_Article_445.pdf
# [*] Downloading PMC7600228 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7600228/pdf/nutrients-12-03082.pdf
# [*] Downloading PMC7554014 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7554014/pdf/11910_2020_Article_1074.pdf
# [x] PDF not found for PMC7551211
# [*] Downloading PMC7543968 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7543968/pdf/262_2020_Article_2725.pdf
# [*] Downloading PMC7504979 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7504979/pdf/adr-4-adr200214.pdf
# [*] Downloading PMC7921135 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7921135/pdf/41401_2020_Article_530.pdf
# [*] Downloading PMC7739965 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7739965/pdf/jad-78-jad200711.pdf
# [*] Downloading PMC7519200 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7519200/pdf/OMCL2020-6782872.pdf
# [*] Downloading PMC7528717 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7528717/pdf/41582_2020_Article_400.pdf
# [*] Downloading PMC7601520 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7601520/pdf/toxins-12-00618.pdf
# [*] Downloading PMC7641316 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7641316/pdf/nihms-1637497.pdf
# [*] Downloading PMC7674315 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7674315/pdf/421_2020_Article_4499.pdf
# [*] Downloading PMC7564294 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7564294/pdf/cells-09-02135.pdf
# [*] Downloading PMC7555120 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7555120/pdf/ijms-21-06914.pdf
# [*] Downloading PMC7555629 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7555629/pdf/ijms-21-06818.pdf
# [*] Downloading PMC7484964 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7484964/pdf/main.pdf
# [*] Downloading PMC7477654 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7477654/pdf/WJSC-12-787.pdf
# [*] Downloading PMC8291993 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC8291993/pdf/nihms-1718940.pdf
# [*] Downloading PMC7572326 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7572326/pdf/10787_2020_Article_751.pdf
# [*] Downloading PMC7489025 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7489025/pdf/13195_2020_Article_678.pdf
# [*] Downloading PMC8819678 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC8819678/pdf/nihms-1771611.pdf
# [*] Downloading PMC7683055 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7683055/pdf/jad-77-jad200610.pdf
# [*] Downloading PMC7683079 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7683079/pdf/jad-77-jad200127.pdf
# [*] Downloading PMC7735207 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7735207/pdf/nihms-1650580.pdf
# [*] Downloading PMC7481199 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7481199/pdf/41419_2020_Article_2953.pdf
# [*] Downloading PMC7479299 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7479299/pdf/11357_2020_Article_261.pdf
# [*] Downloading PMC7563116 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7563116/pdf/biomolecules-10-01276.pdf
# [*] Downloading PMC7504582 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7504582/pdf/ijms-21-06419.pdf
# [*] Downloading PMC7504780 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7504780/pdf/molecules-25-04005.pdf
# [*] Downloading PMC7434571 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7434571/pdf/ijn-15-6113.pdf
# [*] Downloading PMC7504797 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7504797/pdf/molecules-25-03987.pdf
# [*] Downloading PMC9134321 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9134321/pdf/nihms-1805149.pdf
# [*] Downloading PMC7504283 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7504283/pdf/ijms-21-06211.pdf
# [*] Downloading PMC7489816 -> https://www.who.int/wer/2015/wer9006.pdf?ua=1
# [!] Failed to download https://www.who.int/wer/2015/wer9006.pdf?ua=1: 404 Client Error: not found for url: https://www.who.int/wer/2015/wer9006.pdf?ua=1
# [*] Downloading PMC7572873 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7572873/pdf/nihms-1626475.pdf
# [*] Downloading PMC7418707 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7418707/pdf/main.pdf
# [*] Downloading PMC7551693 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7551693/pdf/toxins-12-00546.pdf
# [*] Downloading PMC7485717 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7485717/pdf/aging-12-103867.pdf
# [*] Downloading PMC7413102 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7413102/pdf/fphar-11-01168.pdf
# [*] Downloading PMC7418514 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7418514/pdf/fnmol-13-00137.pdf
# [*] Downloading PMC7503838 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7503838/pdf/ijms-21-06070.pdf
# [*] Downloading PMC7902735 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7902735/pdf/10571_2020_Article_936.pdf
# [*] Downloading PMC7504404 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7504404/pdf/ijms-21-05965.pdf
# [*] Downloading PMC7515854 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7515854/pdf/12035_2020_Article_2054.pdf
# [*] Downloading PMC8318559 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC8318559/pdf/nihms-1718936.pdf
# [*] Downloading PMC7479932 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7479932/pdf/rsob-10-200146.pdf
# [*] Downloading PMC7880921 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7880921/pdf/415_2020_Article_10162.pdf
# [*] Downloading PMC7460933 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7460933/pdf/ijms-21-05783.pdf
# [*] Downloading PMC7692950 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7692950/pdf/GPS-35-1285.pdf
# [*] Downloading PMC7887139 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7887139/pdf/nihms-1630508.pdf
# [*] Downloading PMC7579750 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7579750/pdf/nihms-1636501.pdf
# [*] Downloading PMC7424995 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7424995/pdf/13195_2020_Article_663.pdf
# [*] Downloading PMC7466035 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7466035/pdf/biomolecules-10-01164.pdf
# [*] Downloading PMC7464852 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7464852/pdf/biomolecules-10-01158.pdf
# [*] Downloading PMC7899141 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7899141/pdf/nihms-1670698.pdf
# [*] Downloading PMC7465241 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7465241/pdf/molecules-25-03571.pdf
# [*] Downloading PMC7418046 -> https://pmc.ncbi.nlm.nih.gov/articles/instance/7418046/bin/jamaneurol-e202734-s001.pdf
# [*] Downloading PMC7399253 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7399253/pdf/main.pdf
# [*] Downloading PMC7432772 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7432772/pdf/ijms-21-05485.pdf
# [*] Downloading PMC7466074 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7466074/pdf/biomolecules-10-01134.pdf
# [*] Downloading PMC7398060 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7398060/pdf/12955_2020_Article_1503.pdf
# [*] Downloading PMC7370774 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7370774/pdf/agmr-19-0048.pdf
# [*] Downloading PMC7435578 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7435578/pdf/molecules-25-03413.pdf
# [*] Downloading PMC9661919 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC9661919/pdf/nihms-1846555.pdf
# [*] Downloading PMC7666892 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7666892/pdf/nmaa079.pdf
# [*] Downloading PMC7390234 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7390234/pdf/bmjdrc-2020-001370.pdf
# [*] Downloading PMC7435667 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7435667/pdf/molecules-25-03337.pdf
# [*] Downloading PMC7984263 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7984263/pdf/ALZ-16-1412.pdf
# [*] Downloading PMC8084114 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC8084114/pdf/nihms-1693488.pdf
# [*] Downloading PMC7369141 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7369141/pdf/adr-4-adr200191.pdf
# [*] Downloading PMC7354643 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7354643/pdf/BMRI2020-5120230.pdf
# [*] Downloading PMC7540303 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7540303/pdf/ENE-27-1805.pdf
# [*] Downloading PMC7525853 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7525853/pdf/11357_2020_Article_231.pdf
# [*] Downloading PMC7397171 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7397171/pdf/molecules-25-03291.pdf
# [*] Downloading PMC7400582 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7400582/pdf/biomedicines-08-00228.pdf
# [*] Downloading PMC7419396 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7419396/pdf/40268_2020_Article_316.pdf
# [*] Downloading PMC7344175 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7344175/pdf/f1000research-9-25019.pdf
# [*] Downloading PMC7372915 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7372915/pdf/PRP2-8-e00622.pdf
# [*] Downloading PMC7569385 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7569385/pdf/jnnp-2019-321913.pdf
# [*] Downloading PMC7365083 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7365083/pdf/main.pdf
# [*] Downloading PMC7404195 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7404195/pdf/ijms-21-04920.pdf
# [*] Downloading PMC7404387 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7404387/pdf/ijms-21-04918.pdf
# [*] Downloading PMC7484390 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7484390/pdf/nihms-1618467.pdf
# [*] Downloading PMC7454042 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7454042/pdf/nihms-1621361.pdf
# [*] Downloading PMC7370007 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7370007/pdf/ijerph-17-04878.pdf
# [*] Downloading PMC7812771 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7812771/pdf/nihms-1660710.pdf
# [*] Downloading PMC7335494 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7335494/pdf/main.pdf
# [*] Downloading PMC7400709 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7400709/pdf/nutrients-12-01987.pdf
# [*] Downloading PMC7369795 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7369795/pdf/ijms-21-04665.pdf
# [*] Downloading PMC7335757 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7335757/pdf/11912_2020_Article_940.pdf
# [*] Downloading PMC7320676 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7320676/pdf/main.pdf
# [*] Downloading PMC7666893 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7666893/pdf/nmaa073.pdf
# [*] Downloading PMC10391091 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC10391091/pdf/jmcp.2020.26.7.888.pdf
# [*] Downloading PMC7289916 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7289916/pdf/fnagi-12-00121.pdf
# [*] Downloading PMC7478730 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7478730/pdf/JEM_20200785.pdf
# [*] Downloading PMC7809605 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7809605/pdf/nihms-1660360.pdf
# [*] Downloading PMC7505005 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7505005/pdf/jad-76-jad200134.pdf
# [*] Downloading PMC7380673 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7380673/pdf/PRO-29-1748.pdf
# [*] Downloading PMC7409822 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7409822/pdf/nihms-1607504.pdf
# [*] Downloading PMC7704818 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7704818/pdf/nihms-1605397.pdf
# [*] Downloading PMC7298771 -> https://pmc.ncbi.nlm.nih.gov/articles/PMC7298771/pdf/12877_2020_Article_1607.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1285155722.py in <cell line: 0>()
#     140
#     141 # Uncomment below to run the download.
# --> 142 run_download(CSV_FILE)
#
# /tmp/ipython-input-1285155722.py in run_download(csv_path)
#     129             continue
#     130         pdf_url = get_pdf_link(pmc_id)
# --> 131         time.sleep(WAIT_TIME)
#     132         if pdf_url:
#     133             print(f'[*] Downloading PMC{pmc_id} -> {pdf_url}')
#
# KeyboardInterrupt:
